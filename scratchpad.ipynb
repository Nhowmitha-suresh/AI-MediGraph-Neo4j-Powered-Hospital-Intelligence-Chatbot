# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhowmitha-suresh/AI-MediGraph-Neo4j-Powered-Hospital-Intelligence-Chatbot/blob/main/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: False

# %% [markdown]
# ## Execution Note
#
# GPU resources were unavailable during execution.
# This experiment was run on CPU to validate the pipeline and parameter setup.

# %%
# Simple parameter experiment (no full training)
BATCH_SIZE = 4
TRAIN_STEPS = 100

print("Batch size used:", BATCH_SIZE)
print("Training steps used:", TRAIN_STEPS)
# Out:
# Batch size used: 4
# Training steps used: 100

# %% [markdown]
# ## Observation
#
# Reducing batch size and training steps enables quick testing of the training pipeline
# without requiring long compute time. This approach is useful for preliminary experiments
# and understanding model behavior.
